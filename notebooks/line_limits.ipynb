# %%
import pandas as pd

# %%
branch_df = pd.read_csv("branch_data.txt", sep="\s+")
branch_df.head()
# Out:
#    Unnamed:  0  fbus  tbus        r        x        b  rateA  rateB  rateC  \
# 0         0  0     1     2  0.03030  0.09990  0.02540    114      0      0
# 1         1  1     1     3  0.01290  0.04240  0.01082    114      0      0
# 2         2  2     4     5  0.00176  0.00798  0.00210    114      0      0
# 3         3  3     3     5  0.02410  0.10800  0.02840    114      0      0
# 4         4  4     5     6  0.01190  0.05400  0.01426    114      0      0
#
#    ratio  angle  status  angmin  angmax
# 0    0.0      0       1    -360     360
# 1    0.0      0       1    -360     360
# 2    0.0      0       1    -360     360
# 3    0.0      0       1    -360     360
# 4    0.0      0       1    -360     360

# %%
branch_df["rateA"] = 114
branch_df.head()
# Out:
#    Unnamed: 0  fbus  tbus        r        x        b  rateA  rateB  rateC  \
# 0           0     1     2  0.03030  0.09990  0.02540    114      0      0
# 1           1     1     3  0.01290  0.04240  0.01082    114      0      0
# 2           2     4     5  0.00176  0.00798  0.00210    114      0      0
# 3           3     3     5  0.02410  0.10800  0.02840    114      0      0
# 4           4     5     6  0.01190  0.05400  0.01426    114      0      0
#
#    ratio  angle  status  angmin  angmax
# 0    0.0      0       1    -360     360
# 1    0.0      0       1    -360     360
# 2    0.0      0       1    -360     360
# 3    0.0      0       1    -360     360
# 4    0.0      0       1    -360     360

# %%
branch_df.to_csv("branch_data.txt", sep="\t")
